# %%
#machine laerining

# %%
import pandas as pd
df=pd.read_csv('/content/Salary_dataset.csv')
df.head()
# Out:
#    Unnamed: 0  YearsExperience   Salary
# 0           0              1.2  39344.0
# 1           1              1.4  46206.0
# 2           2              1.6  37732.0
# 3           3              2.1  43526.0
# 4           4              2.3  39892.0

# %%
df.isnull().sum()
# Out:
# Unnamed: 0         0
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
df.drop("Unnamed: 0",axis=1)
# Out:
#     YearsExperience    Salary
# 0               1.2   39344.0
# 1               1.4   46206.0
# 2               1.6   37732.0
# 3               2.1   43526.0
# 4               2.3   39892.0
# 5               3.0   56643.0
# 6               3.1   60151.0
# 7               3.3   54446.0
# 8               3.3   64446.0
# 9               3.8   57190.0
# 10              4.0   63219.0
# 11              4.1   55795.0
# 12              4.1   56958.0
# 13              4.2   57082.0
# 14              4.6   61112.0
# 15              5.0   67939.0
# 16              5.2   66030.0
# 17              5.4   83089.0
# 18              6.0   81364.0
# 19              6.1   93941.0
# 20              6.9   91739.0
# 21              7.2   98274.0
# 22              8.0  101303.0
# 23              8.3  113813.0
# 24              8.8  109432.0
# 25              9.1  105583.0
# 26              9.6  116970.0
# 27              9.7  112636.0
# 28             10.4  122392.0
# 29             10.6  121873.0

# %%
X=df['YearsExperience']
y=df['Salary']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y, test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()

# %%
model.fit(X_train.values.reshape(-1,1),y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(X_test.values.reshape(-1,1))
print("prediction of x test")
print (y_pred)
# Out:
# prediction of x test
# [ 90278.76850835  36370.90902328 124583.76999885 117722.76970075
#   52053.19541894  43231.90932138]

# %%
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error
r2=r2_score(y_test,y_pred)
mae=mean_absolute_error(y_test,y_pred)
mse = mean_squared_error(y_test,y_pred)
print(f"r2 score",r2)
print(f"mean absolute error(MAE):{mae:.2f}")
print(f"mean squared error(MSE): {mse:.2f}")
# Out:
# r2 score 0.9749266460555763
# mean absolute error(MAE):3909.63
# mean squared error(MSE): 25115527.94

# %%
model.predict([[50]])
# Out:
# array([512720.35829133])

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(X_train,y_train,color='red')
plt.plot(X_test,y_pred,color='blue')
plt.title('Salary vs Experience(Training set)')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import numpy as np
experience=np.array([[7.5]]) # Corrected syntax to predict for 7.5 years, made it 2D for model.predict
predicted_salary=model.predict(experience)
print("\npredicted salary for 7.5 years experience ", predicted_salary[0]) # Corrected variable name and spelling in string and variable access
# Out:
# predicted salary for 7.5 years experience  96159.62590671905

# %%
import pandas as pd
df1=pd.read_csv('/content/Exam_Score_Prediction.csv')
df.head()
# Out:
#    Unnamed: 0  YearsExperience   Salary
# 0           0              1.2  39344.0
# 1           1              1.4  46206.0
# 2           2              1.6  37732.0
# 3           3              2.1  43526.0
# 4           4              2.3  39892.0

# %%
df1.isnull().sum()
# Out:
# student_id          0
# age                 0
# gender              0
# course              0
# study_hours         0
# class_attendance    0
# internet_access     0
# sleep_hours         0
# sleep_quality       0
# study_method        0
# facility_rating     0
# exam_difficulty     0
# exam_score          0
# dtype: int64

# %%
df.drop('Unnamed: 0', axis=1, inplace=True)

# %%
df1
# Out:
#        student_id  age  gender   course  study_hours  class_attendance  \
# 0               1   17    male  diploma         2.78              92.9
# 1               2   23   other      bca         3.37              64.8
# 2               3   22    male     b.sc         7.88              76.8
# 3               4   20   other  diploma         0.67              48.4
# 4               5   20  female  diploma         0.89              71.6
# ...           ...  ...     ...      ...          ...               ...
# 19995       19997   18   other      bba         6.50              71.3
# 19996       19998   18    male    b.com         3.71              41.6
# 19997       19999   19   other  diploma         7.88              68.2
# 19998       20000   19    male      bba         4.60              76.3
# 19999       20001   20    male     b.sc         7.50              47.9
#
#       internet_access  sleep_hours sleep_quality   study_method  \
# ...

# %%
df1.drop(['student_id'], axis=1, inplace=True)

# %%
df1 = df1.drop(['gender','course','study_method',
                'internet_access','sleep_quality',
                'exam_difficulty'], axis=1)

# %%
df1
# Out:
#        age  study_hours  class_attendance  sleep_hours facility_rating  \
# 0       17         2.78              92.9          7.4             low
# 1       23         3.37              64.8          4.6          medium
# 2       22         7.88              76.8          8.5            high
# 3       20         0.67              48.4          5.8             low
# 4       20         0.89              71.6          9.8             low
# ...    ...          ...               ...          ...             ...
# 19995   18         6.50              71.3          5.0             low
# 19996   18         3.71              41.6          5.9          medium
# 19997   19         7.88              68.2          4.6             low
# 19998   19         4.60              76.3          6.1          medium
# 19999   20         7.50              47.9          7.5          medium
#
#        exam_score
# 0            58.9
# 1            54.8
# 2            90.3
# 3            29.7
# ...

# %%
y = df1['exam_score']
X = df1[['age','study_hours','class_attendance','sleep_hours']]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y, test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

print("prediction of x test")
print(y_pred)
# Out:
# prediction of x test
# [64.73312435 47.99658996 46.38544895 ... 43.96810591 35.58397806
#  48.54883898]

# %%
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error
r2=r2_score(y_test,y_pred)
mae=mean_absolute_error(y_test,y_pred)
mse = mean_squared_error(y_test,y_pred)
print(f"r2 score",r2)
print(f"mean absolute error(MAE):{mae:.2f}")
print(f"mean squared error(MSE): {mse:.2f}")
# Out:
# r2 score 0.6204325266745427
# mean absolute error(MAE):9.36
# mean squared error(MSE): 134.36

# %%
import seaborn as sns

sns.scatterplot(x='study_hours', y='exam_score', data=df1)
# Out:
# <Axes: xlabel='study_hours', ylabel='exam_score'>

# %%
import numpy as np

Exam_Score_Prediction = np.array(df1['exam_score'])

print(Exam_Score_Prediction[:5])
# Out:
# [58.9 54.8 90.3 29.7 43.7]

# %%
new_data = [[20, 5, 80, 6]]


predicted_score = model.predict(new_data)

print("Predicted Exam Score:", predicted_score)
# Out:
# Predicted Exam Score: [70.22624736]
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
import pandas as pd

new_data = pd.DataFrame({
    'age': [20],
    'study_hours': [5],
    'class_attendance': [80],
    'sleep_hours': [6]
})

predicted_score = model.predict(new_data)

print("Predicted Exam Score:", predicted_score)
# Out:
# Predicted Exam Score: [70.22624736]
