# %% [markdown]
# tokenization - breaking sentences into smaller units or token

# %%
from nltk.tokenize import word_tokenize
import nltk
nltk.download('punkt')
nltk.download('punkt_tab')

text='T love NLP. It is amazing.'
words=word_tokenize(text)
print(words)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# ['T', 'love', 'NLP', '.', 'It', 'is', 'amazing', '.']
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.

# %% [markdown]
# stop word removal- removing word whic don't carry strong meaning

# %%
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
nltk.download('stopwords')
text="T am learning NLP and It is amazing and interesting "
words=word_tokenize(text)
stop_words=set(stopwords.words('english'))
filtered=[w for w in words if w.lower()not in stop_words]
print(filtered)
# Out:
# ['learning', 'NLP', 'amazing', 'interesting']
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# stemming - converting to their roots words

# %%
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize
stemmer=PorterStemmer()
text=['runing','studies','connected']

for word in words:
  print(word+":    "+stemmer.stem(words))
# Out:
# T:    t

# %% [markdown]
# lemmitizer

# %%
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize
nltk.download('wordnet')
lemmatizer=WordNetLemmatizer()
words=['runing','studies','connected']

for word in words:
  print(word+" ->"+lemmatizer.lemmatize(word))
# Out:
# runing ->runing
# studies ->study
# connected ->connected
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
