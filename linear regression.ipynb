# %%
#machine laerining

# %%
import pandas as pd
df=pd.read_csv('/content/Salary_dataset.csv')
df.head()
# Out:
#    Unnamed: 0  YearsExperience   Salary
# 0           0              1.2  39344.0
# 1           1              1.4  46206.0
# 2           2              1.6  37732.0
# 3           3              2.1  43526.0
# 4           4              2.3  39892.0

# %%
df.isnull().sum()
# Out:
# Unnamed: 0         0
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
df.drop("Unnamed: 0",axis=1)
# Out:
#     YearsExperience    Salary
# 0               1.2   39344.0
# 1               1.4   46206.0
# 2               1.6   37732.0
# 3               2.1   43526.0
# 4               2.3   39892.0
# 5               3.0   56643.0
# 6               3.1   60151.0
# 7               3.3   54446.0
# 8               3.3   64446.0
# 9               3.8   57190.0
# 10              4.0   63219.0
# 11              4.1   55795.0
# 12              4.1   56958.0
# 13              4.2   57082.0
# 14              4.6   61112.0
# 15              5.0   67939.0
# 16              5.2   66030.0
# 17              5.4   83089.0
# 18              6.0   81364.0
# 19              6.1   93941.0
# 20              6.9   91739.0
# 21              7.2   98274.0
# 22              8.0  101303.0
# 23              8.3  113813.0
# 24              8.8  109432.0
# 25              9.1  105583.0
# 26              9.6  116970.0
# 27              9.7  112636.0
# 28             10.4  122392.0
# 29             10.6  121873.0

# %%
X=df['YearsExperience']
y=df['Salary']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y, test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()

# %%
model.fit(X_train.values.reshape(-1,1),y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(X_test.values.reshape(-1,1))
print("prediction of x test")
print (y_pred)
# Out:
# prediction of x test
# [ 55579.26799897  45946.0066148   52689.28958372  93148.98739722
#  111452.18402714 125902.07610339]

# %%
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error
r2=r2_score(y_test,y_pred)
mae=mean_absolute_error(y_test,y_pred)
mse = mean_squared_error(y_test,y_pred)
print(f"r2 score",r2)
print(f"mean absolute error(MAE):{mae:.2f}")
print(f"mean squared error(MSE): {mse:.2f}")
# Out:
# r2 score 0.9594869144908774
# mean absolute error(MAE):5649.62
# mean squared error(MSE): 34641381.35

# %%
model.predict([[50]])
# Out:
# array([505452.57463958])

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(X_train,y_train,color='red')
plt.plot(X_test,y_pred,color='blue')
plt.title('Salary vs Experience(Training set)')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import numpy as np
experience=np.array([[7.5]]) # Corrected syntax to predict for 7.5 years, made it 2D for model.predict
predicted_salary=model.predict(experience)
print("\npredicted salary for 7.5 years experience ", predicted_salary[0]) # Corrected variable name and spelling in string and variable access
# Out:
# predicted salary for 7.5 years experience  96038.96581247004
